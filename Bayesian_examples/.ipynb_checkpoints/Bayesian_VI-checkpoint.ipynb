# %% [markdown]
# ### This is a notebook to train a Bayesian neural network with variational inference.
#
# Bayesian neural networks can quantify uncertainties in their prediction. In this notebook a Bayesian neural network is trained with variation inference to learn the function $$ y = 0.4 \sin(4x) + 0.5 \cos(12x) $$
# A zero mean Gaussian random noise with standard deviation $\sigma = 0.05$ is added to the train data. Both the aleatoric (noise in the data) and the epistemic (model uncertainty) uncertaintes are quantified.

# %% [markdown]
# This notebook uses [UQpy](https://uqpyproject.readthedocs.io/en/latest/) which is a general purpose python toolbox for uncertainty quantification. In the following cell we import the necessary libraries to set up the environment to run the code.

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# UQpy imports
from UQpy.scientific_machine_learning.layers import BayesianLayer
from UQpy.scientific_machine_learning.neural_networks import FeedForwardNeuralNetwork
from UQpy.scientific_machine_learning.trainers import BBBTrainer

import logging

logger = logging.getLogger("UQpy")
logger.setLevel(logging.INFO)

torch.manual_seed(0);
np.random.seed(0);

# %% [markdown]
# Once the libraries are loaded, we build the neural network. The neural network consists of 3 hidden layers of widht 20 with ReLu activation function.

# %%
width = 20
network = nn.Sequential(
    BayesianLayer(1, width),
    nn.ReLU(),
    BayesianLayer(width, width),
    nn.ReLU(),
    BayesianLayer(width, width),
    nn.ReLU(),
    BayesianLayer(width, width),
    nn.ReLU(),
    BayesianLayer(width, 1),
)
model = FeedForwardNeuralNetwork(network)

# %% [markdown]
# Now, we define the dataset and the data loader. The dataset class takes the number of samples and the standard deviation of the noise parameter as the input to produce x,y pairs of training data. This class is given as an input to the pytorch DataLoader.

# %%
class SinusoidalDataset(Dataset):
    def __init__(self, n_samples=20, noise_std=0.05):
        self.n_samples = n_samples
        self.noise_std = noise_std
        self.x = torch.cat((torch.linspace(-1, -0.2, int(n_samples/2)),torch.linspace(0.2, 1, int(n_samples/2)))).reshape(-1, 1)
        self.y = torch.tensor(0.4 * np.sin(4 * self.x) + 0.5 * np.cos(12 * self.x) +
                              np.random.normal(0, self.noise_std, self.x.shape), dtype=torch.float)

    def __len__(self):
        return self.n_samples

    def __getitem__(self, item):
        return self.x[item], self.y[item]

train_data = DataLoader(SinusoidalDataset(), batch_size=20, shuffle=True)

# %% [markdown]
# We define the optimizer with the parameters such as the learning rate and call the BBBTrainer implemented in UQpy to learn the parameters of the model.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
trainer = BBBTrainer(model, optimizer)

# %% [markdown]
# Here, we train the model upto a user specified epoch. "beta" is the KL weighting parameter of the ELBO loss and "num_samples" is the number of Monte carlo samples to approximate the log likehood of the data in the ELBO loss.

# %%
print("Starting Training...", end="")
trainer.run(train_data=train_data, epochs=5000, beta=1e-6, num_samples=10)
print("done")
# Out:
# [INFO] - 2024-05-17 16:39:00,945 - UQpy: Scientific Machine Learning: Beginning training FeedForwardNeuralNetwork
# [INFO] - 2024-05-17 16:39:00,957 - UQpy: Scientific Machine Learning: Epoch 1 / 5,000 Train Loss 0.21896103024482727 Train NLL 0.2178865373134613 Train KL 1074.488037109375
# [INFO] - 2024-05-17 16:39:00,962 - UQpy: Scientific Machine Learning: Epoch 2 / 5,000 Train Loss 0.21538278460502625 Train NLL 0.2143125832080841 Train KL 1070.2052001953125
# [INFO] - 2024-05-17 16:39:00,967 - UQpy: Scientific Machine Learning: Epoch 3 / 5,000 Train Loss 0.21683083474636078 Train NLL 0.2157650738954544 Train KL 1065.76513671875
# [INFO] - 2024-05-17 16:39:00,972 - UQpy: Scientific Machine Learning: Epoch 4 / 5,000 Train Loss 0.2174687385559082 Train NLL 0.2164069414138794 Train KL 1061.8037109375
# [INFO] - 2024-05-17 16:39:00,978 - UQpy: Scientific Machine Learning: Epoch 5 / 5,000 Train Loss 0.2161584496498108 Train NLL 0.2151002138853073 Train KL 1058.228515625
# [INFO] - 2024-05-17 16:39:00,984 - UQpy: Scientific Machine Learning: Epoch 6 / 5,000 Train Loss 0.21372760832309723 Train NLL 0.2126728594303131 Train KL 1054.753173828125
# [INFO] - 2024-05-17 16:39:00,989 - UQpy: Scientific Machine Learning: Epoch 7 / 5,000 Train Loss 0.21234914660453796 Train NLL 0.21129770576953888 Train KL 1051.444091796875
# [INFO] - 2024-05-17 16:39:00,994 - UQpy: Scientific Machine Learning: Epoch 8 / 5,000 Train Loss 0.21247722208499908 Train NLL 0.21142902970314026 Train KL 1048.1859130859375
# [INFO] - 2024-05-17 16:39:00,999 - UQpy: Scientific Machine Learning: Epoch 9 / 5,000 Train Loss 0.21342965960502625 Train NLL 0.21238470077514648 Train KL 1044.9630126953125
# [INFO] - 2024-05-17 16:39:01,003 - UQpy: Scientific Machine Learning: Epoch 10 / 5,000 Train Loss 0.21071764826774597 Train NLL 0.20967578887939453 Train KL 1041.8580322265625
# [INFO] - 2024-05-17 16:39:01,008 - UQpy: Scientific Machine Learning: Epoch 11 / 5,000 Train Loss 0.21152539551258087 Train NLL 0.21048662066459656 Train KL 1038.7767333984375
# [INFO] - 2024-05-17 16:39:01,012 - UQpy: Scientific Machine Learning: Epoch 12 / 5,000 Train Loss 0.21222485601902008 Train NLL 0.21118906140327454 Train KL 1035.7979736328125
# [INFO] - 2024-05-17 16:39:01,018 - UQpy: Scientific Machine Learning: Epoch 13 / 5,000 Train Loss 0.21140585839748383 Train NLL 0.2103728950023651 Train KL 1032.9627685546875
# [INFO] - 2024-05-17 16:39:01,022 - UQpy: Scientific Machine Learning: Epoch 14 / 5,000 Train Loss 0.21170032024383545 Train NLL 0.21067023277282715 Train KL 1030.08837890625
# [INFO] - 2024-05-17 16:39:01,028 - UQpy: Scientific Machine Learning: Epoch 15 / 5,000 Train Loss 0.2114892154932022 Train NLL 0.2104620635509491 Train KL 1027.15380859375
# [INFO] - 2024-05-17 16:39:01,033 - UQpy: Scientific Machine Learning: Epoch 16 / 5,000 Train Loss 0.21119260787963867 Train NLL 0.2101685255765915 Train KL 1024.074951171875
# [INFO] - 2024-05-17 16:39:01,038 - UQpy: Scientific Machine Learning: Epoch 17 / 5,000 Train Loss 0.2115456610918045 Train NLL 0.21052458882331848 Train KL 1021.072998046875
# [INFO] - 2024-05-17 16:39:01,043 - UQpy: Scientific Machine Learning: Epoch 18 / 5,000 Train Loss 0.21244843304157257 Train NLL 0.2114303559064865 Train KL 1018.0708618164062
# [INFO] - 2024-05-17 16:39:01,047 - UQpy: Scientific Machine Learning: Epoch 19 / 5,000 Train Loss 0.2139723300933838 Train NLL 0.21295718848705292 Train KL 1015.1442260742188
# [INFO] - 2024-05-17 16:39:01,052 - UQpy: Scientific Machine Learning: Epoch 20 / 5,000 Train Loss 0.21198952198028564 Train NLL 0.21097736060619354 Train KL 1012.1669311523438
# [INFO] - 2024-05-17 16:39:01,057 - UQpy: Scientific Machine Learning: Epoch 21 / 5,000 Train Loss 0.21038039028644562 Train NLL 0.20937123894691467 Train KL 1009.146728515625
# [INFO] - 2024-05-17 16:39:01,061 - UQpy: Scientific Machine Learning: Epoch 22 / 5,000 Train Loss 0.2109503298997879 Train NLL 0.20994417369365692 Train KL 1006.1578369140625
# [INFO] - 2024-05-17 16:39:01,066 - UQpy: Scientific Machine Learning: Epoch 23 / 5,000 Train Loss 0.21094584465026855 Train NLL 0.20994262397289276 Train KL 1003.2234497070312
# [INFO] - 2024-05-17 16:39:01,071 - UQpy: Scientific Machine Learning: Epoch 24 / 5,000 Train Loss 0.21042534708976746 Train NLL 0.20942501723766327 Train KL 1000.331787109375
# [INFO] - 2024-05-17 16:39:01,075 - UQpy: Scientific Machine Learning: Epoch 25 / 5,000 Train Loss 0.2137378752231598 Train NLL 0.2127404659986496 Train KL 997.4063110351562
# [INFO] - 2024-05-17 16:39:01,080 - UQpy: Scientific Machine Learning: Epoch 26 / 5,000 Train Loss 0.21149039268493652 Train NLL 0.21049591898918152 Train KL 994.4700927734375
# [INFO] - 2024-05-17 16:39:01,085 - UQpy: Scientific Machine Learning: Epoch 27 / 5,000 Train Loss 0.21180100739002228 Train NLL 0.21080954372882843 Train KL 991.4583129882812
# [INFO] - 2024-05-17 16:39:01,089 - UQpy: Scientific Machine Learning: Epoch 28 / 5,000 Train Loss 0.21086710691452026 Train NLL 0.20987871289253235 Train KL 988.3971557617188
# [INFO] - 2024-05-17 16:39:01,095 - UQpy: Scientific Machine Learning: Epoch 29 / 5,000 Train Loss 0.21020963788032532 Train NLL 0.20922429859638214 Train KL 985.3410034179688
# [INFO] - 2024-05-17 16:39:01,100 - UQpy: Scientific Machine Learning: Epoch 30 / 5,000 Train Loss 0.21169443428516388 Train NLL 0.21071211993694305 Train KL 982.3096313476562
# [INFO] - 2024-05-17 16:39:01,105 - UQpy: Scientific Machine Learning: Epoch 31 / 5,000 Train Loss 0.21190084517002106 Train NLL 0.2109214961528778 Train KL 979.3507690429688
# [INFO] - 2024-05-17 16:39:01,110 - UQpy: Scientific Machine Learning: Epoch 32 / 5,000 Train Loss 0.21062380075454712 Train NLL 0.20964744687080383 Train KL 976.3529663085938
# [INFO] - 2024-05-17 16:39:01,114 - UQpy: Scientific Machine Learning: Epoch 33 / 5,000 Train Loss 0.2100374549627304 Train NLL 0.20906388759613037 Train KL 973.5651245117188
# [INFO] - 2024-05-17 16:39:01,119 - UQpy: Scientific Machine Learning: Epoch 34 / 5,000 Train Loss 0.2117166519165039 Train NLL 0.2107458859682083 Train KL 970.7706909179688
# [INFO] - 2024-05-17 16:39:01,124 - UQpy: Scientific Machine Learning: Epoch 35 / 5,000 Train Loss 0.21172966063022614 Train NLL 0.21076162159442902 Train KL 968.0413818359375
# [INFO] - 2024-05-17 16:39:01,128 - UQpy: Scientific Machine Learning: Epoch 36 / 5,000 Train Loss 0.21117161214351654 Train NLL 0.21020612120628357 Train KL 965.4938354492188
# [INFO] - 2024-05-17 16:39:01,133 - UQpy: Scientific Machine Learning: Epoch 37 / 5,000 Train Loss 0.21072065830230713 Train NLL 0.20975761115550995 Train KL 963.0491333007812
# [INFO] - 2024-05-17 16:39:01,137 - UQpy: Scientific Machine Learning: Epoch 38 / 5,000 Train Loss 0.20992332696914673 Train NLL 0.20896276831626892 Train KL 960.5559692382812
# [INFO] - 2024-05-17 16:39:01,142 - UQpy: Scientific Machine Learning: Epoch 39 / 5,000 Train Loss 0.21052302420139313 Train NLL 0.20956487953662872 Train KL 958.1455688476562
# Starting Training...
# [INFO] - 2024-05-17 16:39:01,147 - UQpy: Scientific Machine Learning: Epoch 40 / 5,000 Train Loss 0.21144375205039978 Train NLL 0.210487961769104 Train KL 955.7841186523438
# [INFO] - 2024-05-17 16:39:01,152 - UQpy: Scientific Machine Learning: Epoch 41 / 5,000 Train Loss 0.21103395521640778 Train NLL 0.2100805789232254 Train KL 953.3786010742188
# [INFO] - 2024-05-17 16:39:01,157 - UQpy: Scientific Machine Learning: Epoch 42 / 5,000 Train Loss 0.21068885922431946 Train NLL 0.20973792672157288 Train KL 950.9287109375
# [INFO] - 2024-05-17 16:39:01,162 - UQpy: Scientific Machine Learning: Epoch 43 / 5,000 Train Loss 0.2124316245317459 Train NLL 0.21148307621479034 Train KL 948.5455322265625
# [INFO] - 2024-05-17 16:39:01,166 - UQpy: Scientific Machine Learning: Epoch 44 / 5,000 Train Loss 0.21202293038368225 Train NLL 0.2110767811536789 Train KL 946.1526489257812
# [INFO] - 2024-05-17 16:39:01,171 - UQpy: Scientific Machine Learning: Epoch 45 / 5,000 Train Loss 0.21154311299324036 Train NLL 0.21059927344322205 Train KL 943.8370361328125
# [INFO] - 2024-05-17 16:39:01,176 - UQpy: Scientific Machine Learning: Epoch 46 / 5,000 Train Loss 0.21160268783569336 Train NLL 0.2106611728668213 Train KL 941.5204467773438
# [INFO] - 2024-05-17 16:39:01,180 - UQpy: Scientific Machine Learning: Epoch 47 / 5,000 Train Loss 0.21009236574172974 Train NLL 0.20915310084819794 Train KL 939.2588500976562
# [INFO] - 2024-05-17 16:39:01,185 - UQpy: Scientific Machine Learning: Epoch 48 / 5,000 Train Loss 0.21116524934768677 Train NLL 0.21022816002368927 Train KL 937.0930786132812
# [INFO] - 2024-05-17 16:39:01,190 - UQpy: Scientific Machine Learning: Epoch 49 / 5,000 Train Loss 0.21116755902767181 Train NLL 0.21023258566856384 Train KL 934.9771728515625
# [INFO] - 2024-05-17 16:39:01,194 - UQpy: Scientific Machine Learning: Epoch 50 / 5,000 Train Loss 0.21011894941329956 Train NLL 0.20918600261211395 Train KL 932.9521484375
# [INFO] - 2024-05-17 16:39:01,199 - UQpy: Scientific Machine Learning: Epoch 51 / 5,000 Train Loss 0.21034285426139832 Train NLL 0.20941194891929626 Train KL 930.90673828125
# [INFO] - 2024-05-17 16:39:01,204 - UQpy: Scientific Machine Learning: Epoch 52 / 5,000 Train Loss 0.21439813077449799 Train NLL 0.21346910297870636 Train KL 929.0255126953125
# [INFO] - 2024-05-17 16:39:01,208 - UQpy: Scientific Machine Learning: Epoch 53 / 5,000 Train Loss 0.2105245441198349 Train NLL 0.20959720015525818 Train KL 927.3419189453125
# [INFO] - 2024-05-17 16:39:01,213 - UQpy: Scientific Machine Learning: Epoch 54 / 5,000 Train Loss 0.21098065376281738 Train NLL 0.2100549042224884 Train KL 925.7506713867188
# [INFO] - 2024-05-17 16:39:01,218 - UQpy: Scientific Machine Learning: Epoch 55 / 5,000 Train Loss 0.2103767991065979 Train NLL 0.20945265889167786 Train KL 924.1351318359375
# [INFO] - 2024-05-17 16:39:01,223 - UQpy: Scientific Machine Learning: Epoch 56 / 5,000 Train Loss 0.2097034454345703 Train NLL 0.20878079533576965 Train KL 922.6444091796875
# [INFO] - 2024-05-17 16:39:01,228 - UQpy: Scientific Machine Learning: Epoch 57 / 5,000 Train Loss 0.21054089069366455 Train NLL 0.20961971580982208 Train KL 921.1749877929688
# [INFO] - 2024-05-17 16:39:01,233 - UQpy: Scientific Machine Learning: Epoch 58 / 5,000 Train Loss 0.21224217116832733 Train NLL 0.2113223373889923 Train KL 919.8367309570312
# [INFO] - 2024-05-17 16:39:01,239 - UQpy: Scientific Machine Learning: Epoch 59 / 5,000 Train Loss 0.21091587841510773 Train NLL 0.209997296333313 Train KL 918.5838623046875
# [INFO] - 2024-05-17 16:39:01,243 - UQpy: Scientific Machine Learning: Epoch 60 / 5,000 Train Loss 0.21108940243721008 Train NLL 0.21017196774482727 Train KL 917.4400634765625
# [INFO] - 2024-05-17 16:39:01,248 - UQpy: Scientific Machine Learning: Epoch 61 / 5,000 Train Loss 0.21446079015731812 Train NLL 0.21354439854621887 Train KL 916.3857421875
# [INFO] - 2024-05-17 16:39:01,253 - UQpy: Scientific Machine Learning: Epoch 62 / 5,000 Train Loss 0.21024446189403534 Train NLL 0.20932909846305847 Train KL 915.367919921875
# [INFO] - 2024-05-17 16:39:01,257 - UQpy: Scientific Machine Learning: Epoch 63 / 5,000 Train Loss 0.21102622151374817 Train NLL 0.21011178195476532 Train KL 914.4437255859375
# [INFO] - 2024-05-17 16:39:01,262 - UQpy: Scientific Machine Learning: Epoch 64 / 5,000 Train Loss 0.21066589653491974 Train NLL 0.20975227653980255 Train KL 913.617431640625
# [INFO] - 2024-05-17 16:39:01,267 - UQpy: Scientific Machine Learning: Epoch 65 / 5,000 Train Loss 0.21142108738422394 Train NLL 0.21050822734832764 Train KL 912.8597412109375
# [INFO] - 2024-05-17 16:39:01,272 - UQpy: Scientific Machine Learning: Epoch 66 / 5,000 Train Loss 0.21140825748443604 Train NLL 0.2104962319135666 Train KL 912.021484375
# [INFO] - 2024-05-17 16:39:01,276 - UQpy: Scientific Machine Learning: Epoch 67 / 5,000 Train Loss 0.21065624058246613 Train NLL 0.20974493026733398 Train KL 911.3070678710938
# [INFO] - 2024-05-17 16:39:01,281 - UQpy: Scientific Machine Learning: Epoch 68 / 5,000 Train Loss 0.2106323093175888 Train NLL 0.20972172915935516 Train KL 910.5821533203125
# [INFO] - 2024-05-17 16:39:01,286 - UQpy: Scientific Machine Learning: Epoch 69 / 5,000 Train Loss 0.2104180008172989 Train NLL 0.209508016705513 Train KL 909.9840087890625
# [INFO] - 2024-05-17 16:39:01,290 - UQpy: Scientific Machine Learning: Epoch 70 / 5,000 Train Loss 0.21043486893177032 Train NLL 0.20952539145946503 Train KL 909.4798583984375
# [INFO] - 2024-05-17 16:39:01,295 - UQpy: Scientific Machine Learning: Epoch 71 / 5,000 Train Loss 0.20919549465179443 Train NLL 0.20828655362129211 Train KL 908.9450073242188
# [INFO] - 2024-05-17 16:39:01,300 - UQpy: Scientific Machine Learning: Epoch 72 / 5,000 Train Loss 0.21101014316082 Train NLL 0.2101016491651535 Train KL 908.4898071289062
# [INFO] - 2024-05-17 16:39:01,304 - UQpy: Scientific Machine Learning: Epoch 73 / 5,000 Train Loss 0.21071723103523254 Train NLL 0.20980927348136902 Train KL 907.9548950195312
# [INFO] - 2024-05-17 16:39:01,310 - UQpy: Scientific Machine Learning: Epoch 74 / 5,000 Train Loss 0.2095937430858612 Train NLL 0.20868615806102753 Train KL 907.5790405273438
# [INFO] - 2024-05-17 16:39:01,314 - UQpy: Scientific Machine Learning: Epoch 75 / 5,000 Train Loss 0.21181707084178925 Train NLL 0.21090981364250183 Train KL 907.2630615234375
# [INFO] - 2024-05-17 16:39:01,319 - UQpy: Scientific Machine Learning: Epoch 76 / 5,000 Train Loss 0.2086697220802307 Train NLL 0.20776256918907166 Train KL 907.1531982421875
# [INFO] - 2024-05-17 16:39:01,324 - UQpy: Scientific Machine Learning: Epoch 77 / 5,000 Train Loss 0.21054887771606445 Train NLL 0.20964166522026062 Train KL 907.2077026367188
# [INFO] - 2024-05-17 16:39:01,328 - UQpy: Scientific Machine Learning: Epoch 78 / 5,000 Train Loss 0.20834985375404358 Train NLL 0.20744264125823975 Train KL 907.2119750976562
# [INFO] - 2024-05-17 16:39:01,333 - UQpy: Scientific Machine Learning: Epoch 79 / 5,000 Train Loss 0.21186329424381256 Train NLL 0.21095602214336395 Train KL 907.2651977539062
# [INFO] - 2024-05-17 16:39:01,338 - UQpy: Scientific Machine Learning: Epoch 80 / 5,000 Train Loss 0.20937371253967285 Train NLL 0.20846638083457947 Train KL 907.3284912109375
# [INFO] - 2024-05-17 16:39:01,342 - UQpy: Scientific Machine Learning: Epoch 81 / 5,000 Train Loss 0.20931948721408844 Train NLL 0.20841214060783386 Train KL 907.341552734375
# [INFO] - 2024-05-17 16:39:01,347 - UQpy: Scientific Machine Learning: Epoch 82 / 5,000 Train Loss 0.20981353521347046 Train NLL 0.20890605449676514 Train KL 907.4776611328125
# [INFO] - 2024-05-17 16:39:01,352 - UQpy: Scientific Machine Learning: Epoch 83 / 5,000 Train Loss 0.2108406275510788 Train NLL 0.2099328488111496 Train KL 907.7762451171875
# [INFO] - 2024-05-17 16:39:01,357 - UQpy: Scientific Machine Learning: Epoch 84 / 5,000 Train Loss 0.20941917598247528 Train NLL 0.20851099491119385 Train KL 908.1841430664062
# [INFO] - 2024-05-17 16:39:01,362 - UQpy: Scientific Machine Learning: Epoch 85 / 5,000 Train Loss 0.21116329729557037 Train NLL 0.21025459468364716 Train KL 908.7044067382812
# [INFO] - 2024-05-17 16:39:01,366 - UQpy: Scientific Machine Learning: Epoch 86 / 5,000 Train Loss 0.20848561823368073 Train NLL 0.20757634937763214 Train KL 909.2718505859375
# [INFO] - 2024-05-17 16:39:01,371 - UQpy: Scientific Machine Learning: Epoch 87 / 5,000 Train Loss 0.21099478006362915 Train NLL 0.21008482575416565 Train KL 909.959228515625
# [INFO] - 2024-05-17 16:39:01,376 - UQpy: Scientific Machine Learning: Epoch 88 / 5,000 Train Loss 0.2081776112318039 Train NLL 0.20726676285266876 Train KL 910.8552856445312
# [INFO] - 2024-05-17 16:39:01,381 - UQpy: Scientific Machine Learning: Epoch 89 / 5,000 Train Loss 0.2103872299194336 Train NLL 0.20947527885437012 Train KL 911.95654296875
# [INFO] - 2024-05-17 16:39:01,386 - UQpy: Scientific Machine Learning: Epoch 90 / 5,000 Train Loss 0.20982562005519867 Train NLL 0.20891228318214417 Train KL 913.3386840820312
# [INFO] - 2024-05-17 16:39:01,390 - UQpy: Scientific Machine Learning: Epoch 91 / 5,000 Train Loss 0.2072633057832718 Train NLL 0.20634865760803223 Train KL 914.64599609375
# [INFO] - 2024-05-17 16:39:01,394 - UQpy: Scientific Machine Learning: Epoch 92 / 5,000 Train Loss 0.20734818279743195 Train NLL 0.2064320594072342 Train KL 916.1282958984375
# [INFO] - 2024-05-17 16:39:01,399 - UQpy: Scientific Machine Learning: Epoch 93 / 5,000 Train Loss 0.20789660513401031 Train NLL 0.20697884261608124 Train KL 917.7594604492188
# [INFO] - 2024-05-17 16:39:01,404 - UQpy: Scientific Machine Learning: Epoch 94 / 5,000 Train Loss 0.20602770149707794 Train NLL 0.2051081657409668 Train KL 919.5386352539062
# [INFO] - 2024-05-17 16:39:01,409 - UQpy: Scientific Machine Learning: Epoch 95 / 5,000 Train Loss 0.20720846951007843 Train NLL 0.2062869369983673 Train KL 921.5342407226562
# [INFO] - 2024-05-17 16:39:01,414 - UQpy: Scientific Machine Learning: Epoch 96 / 5,000 Train Loss 0.20789635181427002 Train NLL 0.20697280764579773 Train KL 923.5428466796875
# [INFO] - 2024-05-17 16:39:01,418 - UQpy: Scientific Machine Learning: Epoch 97 / 5,000 Train Loss 0.2057056725025177 Train NLL 0.20478007197380066 Train KL 925.5968627929688
# [INFO] - 2024-05-17 16:39:01,423 - UQpy: Scientific Machine Learning: Epoch 98 / 5,000 Train Loss 0.20826883614063263 Train NLL 0.2073410004377365 Train KL 927.8359985351562
# [INFO] - 2024-05-17 16:39:01,427 - UQpy: Scientific Machine Learning: Epoch 99 / 5,000 Train Loss 0.20846280455589294 Train NLL 0.20753273367881775 Train KL 930.0772705078125
# [INFO] - 2024-05-17 16:39:01,433 - UQpy: Scientific Machine Learning: Epoch 100 / 5,000 Train Loss 0.205724835395813 Train NLL 0.20479238033294678 Train KL 932.458740234375
# [INFO] - 2024-05-17 16:39:01,438 - UQpy: Scientific Machine Learning: Epoch 101 / 5,000 Train Loss 0.2059253305196762 Train NLL 0.20499031245708466 Train KL 935.0184326171875
# [INFO] - 2024-05-17 16:39:01,443 - UQpy: Scientific Machine Learning: Epoch 102 / 5,000 Train Loss 0.20605723559856415 Train NLL 0.2051195204257965 Train KL 937.7078857421875
# [INFO] - 2024-05-17 16:39:01,448 - UQpy: Scientific Machine Learning: Epoch 103 / 5,000 Train Loss 0.2058926522731781 Train NLL 0.2049521654844284 Train KL 940.4900512695312
# [INFO] - 2024-05-17 16:39:01,452 - UQpy: Scientific Machine Learning: Epoch 104 / 5,000 Train Loss 0.20519492030143738 Train NLL 0.20425155758857727 Train KL 943.3676147460938
# [INFO] - 2024-05-17 16:39:01,458 - UQpy: Scientific Machine Learning: Epoch 105 / 5,000 Train Loss 0.20334012806415558 Train NLL 0.20239374041557312 Train KL 946.3905639648438
# [INFO] - 2024-05-17 16:39:01,462 - UQpy: Scientific Machine Learning: Epoch 106 / 5,000 Train Loss 0.20437407493591309 Train NLL 0.20342454314231873 Train KL 949.5256958007812
# [INFO] - 2024-05-17 16:39:01,467 - UQpy: Scientific Machine Learning: Epoch 107 / 5,000 Train Loss 0.20368541777133942 Train NLL 0.20273280143737793 Train KL 952.6190185546875
# [INFO] - 2024-05-17 16:39:01,472 - UQpy: Scientific Machine Learning: Epoch 108 / 5,000 Train Loss 0.2053116112947464 Train NLL 0.20435559749603271 Train KL 956.0130004882812
# [INFO] - 2024-05-17 16:39:01,477 - UQpy: Scientific Machine Learning: Epoch 109 / 5,000 Train Loss 0.20372788608074188 Train NLL 0.20276837050914764 Train KL 959.5137329101562
# [INFO] - 2024-05-17 16:39:01,482 - UQpy: Scientific Machine Learning: Epoch 110 / 5,000 Train Loss 0.20267006754875183 Train NLL 0.20170700550079346 Train KL 963.0552368164062
# [INFO] - 2024-05-17 16:39:01,487 - UQpy: Scientific Machine Learning: Epoch 111 / 5,000 Train Loss 0.20353515446186066 Train NLL 0.20256857573986053 Train KL 966.5826416015625
# [INFO] - 2024-05-17 16:39:01,492 - UQpy: Scientific Machine Learning: Epoch 112 / 5,000 Train Loss 0.20437951385974884 Train NLL 0.20340938866138458 Train KL 970.1260986328125
# [INFO] - 2024-05-17 16:39:01,496 - UQpy: Scientific Machine Learning: Epoch 113 / 5,000 Train Loss 0.20198994874954224 Train NLL 0.20101630687713623 Train KL 973.641357421875
# [INFO] - 2024-05-17 16:39:01,501 - UQpy: Scientific Machine Learning: Epoch 114 / 5,000 Train Loss 0.20156240463256836 Train NLL 0.20058520138263702 Train KL 977.2083740234375
# [INFO] - 2024-05-17 16:39:01,506 - UQpy: Scientific Machine Learning: Epoch 115 / 5,000 Train Loss 0.2036413848400116 Train NLL 0.20266056060791016 Train KL 980.8290405273438
# [INFO] - 2024-05-17 16:39:01,510 - UQpy: Scientific Machine Learning: Epoch 116 / 5,000 Train Loss 0.20123013854026794 Train NLL 0.20024602115154266 Train KL 984.1236572265625
# [INFO] - 2024-05-17 16:39:01,515 - UQpy: Scientific Machine Learning: Epoch 117 / 5,000 Train Loss 0.20207332074642181 Train NLL 0.20108577609062195 Train KL 987.5424194335938
# [INFO] - 2024-05-17 16:39:01,520 - UQpy: Scientific Machine Learning: Epoch 118 / 5,000 Train Loss 0.20038090646266937 Train NLL 0.19938994944095612 Train KL 990.9525756835938
# [INFO] - 2024-05-17 16:39:01,524 - UQpy: Scientific Machine Learning: Epoch 119 / 5,000 Train Loss 0.20149818062782288 Train NLL 0.20050375163555145 Train KL 994.434814453125
# [INFO] - 2024-05-17 16:39:01,529 - UQpy: Scientific Machine Learning: Epoch 120 / 5,000 Train Loss 0.20064759254455566 Train NLL 0.1996496021747589 Train KL 997.9861450195312
# [INFO] - 2024-05-17 16:39:01,534 - UQpy: Scientific Machine Learning: Epoch 121 / 5,000 Train Loss 0.19980256259441376 Train NLL 0.1988012194633484 Train KL 1001.3480224609375
# [INFO] - 2024-05-17 16:39:01,538 - UQpy: Scientific Machine Learning: Epoch 122 / 5,000 Train Loss 0.19937849044799805 Train NLL 0.19837374985218048 Train KL 1004.7367553710938
# [INFO] - 2024-05-17 16:39:01,543 - UQpy: Scientific Machine Learning: Epoch 123 / 5,000 Train Loss 0.20039322972297668 Train NLL 0.19938522577285767 Train KL 1008.0064086914062
# [INFO] - 2024-05-17 16:39:01,549 - UQpy: Scientific Machine Learning: Epoch 124 / 5,000 Train Loss 0.20020532608032227 Train NLL 0.19919417798519135 Train KL 1011.1468505859375
# [INFO] - 2024-05-17 16:39:01,554 - UQpy: Scientific Machine Learning: Epoch 125 / 5,000 Train Loss 0.19908039271831512 Train NLL 0.1980663239955902 Train KL 1014.0680541992188
# [INFO] - 2024-05-17 16:39:01,559 - UQpy: Scientific Machine Learning: Epoch 126 / 5,000 Train Loss 0.19962739944458008 Train NLL 0.19861045479774475 Train KL 1016.939697265625
# [INFO] - 2024-05-17 16:39:01,564 - UQpy: Scientific Machine Learning: Epoch 127 / 5,000 Train Loss 0.19826173782348633 Train NLL 0.1972421556711197 Train KL 1019.5797119140625
# [INFO] - 2024-05-17 16:39:01,569 - UQpy: Scientific Machine Learning: Epoch 128 / 5,000 Train Loss 0.19929815828800201 Train NLL 0.1982761025428772 Train KL 1022.0553588867188
# [INFO] - 2024-05-17 16:39:01,575 - UQpy: Scientific Machine Learning: Epoch 129 / 5,000 Train Loss 0.19975422322750092 Train NLL 0.19872960448265076 Train KL 1024.6258544921875
# [INFO] - 2024-05-17 16:39:01,580 - UQpy: Scientific Machine Learning: Epoch 130 / 5,000 Train Loss 0.1986352503299713 Train NLL 0.19760818779468536 Train KL 1027.06982421875
# [INFO] - 2024-05-17 16:39:01,585 - UQpy: Scientific Machine Learning: Epoch 131 / 5,000 Train Loss 0.19833533465862274 Train NLL 0.19730588793754578 Train KL 1029.4503173828125
# [INFO] - 2024-05-17 16:39:01,590 - UQpy: Scientific Machine Learning: Epoch 132 / 5,000 Train Loss 0.19875693321228027 Train NLL 0.1977251023054123 Train KL 1031.826416015625
# [INFO] - 2024-05-17 16:39:01,594 - UQpy: Scientific Machine Learning: Epoch 133 / 5,000 Train Loss 0.19865234196186066 Train NLL 0.1976180076599121 Train KL 1034.3341064453125
# [INFO] - 2024-05-17 16:39:01,599 - UQpy: Scientific Machine Learning: Epoch 134 / 5,000 Train Loss 0.19856470823287964 Train NLL 0.1975277215242386 Train KL 1036.9830322265625
# [INFO] - 2024-05-17 16:39:01,603 - UQpy: Scientific Machine Learning: Epoch 135 / 5,000 Train Loss 0.19748267531394958 Train NLL 0.1964431256055832 Train KL 1039.543701171875
# [INFO] - 2024-05-17 16:39:01,608 - UQpy: Scientific Machine Learning: Epoch 136 / 5,000 Train Loss 0.19711217284202576 Train NLL 0.19607026875019073 Train KL 1041.8974609375
# [INFO] - 2024-05-17 16:39:01,613 - UQpy: Scientific Machine Learning: Epoch 137 / 5,000 Train Loss 0.1973329484462738 Train NLL 0.1962885707616806 Train KL 1044.384765625
# [INFO] - 2024-05-17 16:39:01,618 - UQpy: Scientific Machine Learning: Epoch 138 / 5,000 Train Loss 0.19924351572990417 Train NLL 0.1981968730688095 Train KL 1046.64208984375
# [INFO] - 2024-05-17 16:39:01,622 - UQpy: Scientific Machine Learning: Epoch 139 / 5,000 Train Loss 0.19594351947307587 Train NLL 0.19489458203315735 Train KL 1048.9334716796875
# [INFO] - 2024-05-17 16:39:01,627 - UQpy: Scientific Machine Learning: Epoch 140 / 5,000 Train Loss 0.19671329855918884 Train NLL 0.1956622302532196 Train KL 1051.0679931640625
# [INFO] - 2024-05-17 16:39:01,632 - UQpy: Scientific Machine Learning: Epoch 141 / 5,000 Train Loss 0.19611632823944092 Train NLL 0.1950630247592926 Train KL 1053.3076171875
# [INFO] - 2024-05-17 16:39:01,636 - UQpy: Scientific Machine Learning: Epoch 142 / 5,000 Train Loss 0.19661857187747955 Train NLL 0.1955629587173462 Train KL 1055.606689453125
# [INFO] - 2024-05-17 16:39:01,641 - UQpy: Scientific Machine Learning: Epoch 143 / 5,000 Train Loss 0.1967775672674179 Train NLL 0.19571977853775024 Train KL 1057.7852783203125
# [INFO] - 2024-05-17 16:39:01,646 - UQpy: Scientific Machine Learning: Epoch 144 / 5,000 Train Loss 0.1966235190629959 Train NLL 0.19556337594985962 Train KL 1060.14697265625
# [INFO] - 2024-05-17 16:39:01,651 - UQpy: Scientific Machine Learning: Epoch 145 / 5,000 Train Loss 0.19636981189250946 Train NLL 0.19530722498893738 Train KL 1062.5848388671875
# [INFO] - 2024-05-17 16:39:01,655 - UQpy: Scientific Machine Learning: Epoch 146 / 5,000 Train Loss 0.19559790194034576 Train NLL 0.19453275203704834 Train KL 1065.1549072265625
# [INFO] - 2024-05-17 16:39:01,660 - UQpy: Scientific Machine Learning: Epoch 147 / 5,000 Train Loss 0.19805844128131866 Train NLL 0.19699090719223022 Train KL 1067.5333251953125
# [INFO] - 2024-05-17 16:39:01,664 - UQpy: Scientific Machine Learning: Epoch 148 / 5,000 Train Loss 0.19537687301635742 Train NLL 0.1943071186542511 Train KL 1069.7490234375
# [INFO] - 2024-05-17 16:39:01,669 - UQpy: Scientific Machine Learning: Epoch 149 / 5,000 Train Loss 0.1961274892091751 Train NLL 0.19505546987056732 Train KL 1072.019287109375
# [INFO] - 2024-05-17 16:39:01,673 - UQpy: Scientific Machine Learning: Epoch 150 / 5,000 Train Loss 0.19601847231388092 Train NLL 0.19494430720806122 Train KL 1074.16064453125
# [INFO] - 2024-05-17 16:39:01,678 - UQpy: Scientific Machine Learning: Epoch 151 / 5,000 Train Loss 0.19333744049072266 Train NLL 0.19226117432117462 Train KL 1076.27099609375
# [INFO] - 2024-05-17 16:39:01,683 - UQpy: Scientific Machine Learning: Epoch 152 / 5,000 Train Loss 0.19722585380077362 Train NLL 0.19614730775356293 Train KL 1078.5531005859375
# [INFO] - 2024-05-17 16:39:01,688 - UQpy: Scientific Machine Learning: Epoch 153 / 5,000 Train Loss 0.19592098891735077 Train NLL 0.19484010338783264 Train KL 1080.8812255859375
# [INFO] - 2024-05-17 16:39:01,693 - UQpy: Scientific Machine Learning: Epoch 154 / 5,000 Train Loss 0.19567163288593292 Train NLL 0.19458810985088348 Train KL 1083.521484375
# [INFO] - 2024-05-17 16:39:01,698 - UQpy: Scientific Machine Learning: Epoch 155 / 5,000 Train Loss 0.19599393010139465 Train NLL 0.19490759074687958 Train KL 1086.3428955078125
# [INFO] - 2024-05-17 16:39:01,702 - UQpy: Scientific Machine Learning: Epoch 156 / 5,000 Train Loss 0.19474858045578003 Train NLL 0.19365915656089783 Train KL 1089.4229736328125
# [INFO] - 2024-05-17 16:39:01,707 - UQpy: Scientific Machine Learning: Epoch 157 / 5,000 Train Loss 0.19733738899230957 Train NLL 0.1962447166442871 Train KL 1092.668701171875
# [INFO] - 2024-05-17 16:39:01,711 - UQpy: Scientific Machine Learning: Epoch 158 / 5,000 Train Loss 0.1940433531999588 Train NLL 0.19294729828834534 Train KL 1096.0517578125
# [INFO] - 2024-05-17 16:39:01,716 - UQpy: Scientific Machine Learning: Epoch 159 / 5,000 Train Loss 0.1941315084695816 Train NLL 0.19303187727928162 Train KL 1099.6297607421875
# [INFO] - 2024-05-17 16:39:01,720 - UQpy: Scientific Machine Learning: Epoch 160 / 5,000 Train Loss 0.1923828423023224 Train NLL 0.19127947092056274 Train KL 1103.3704833984375
# [INFO] - 2024-05-17 16:39:01,725 - UQpy: Scientific Machine Learning: Epoch 161 / 5,000 Train Loss 0.193806990981102 Train NLL 0.19269971549510956 Train KL 1107.270263671875
# [INFO] - 2024-05-17 16:39:01,729 - UQpy: Scientific Machine Learning: Epoch 162 / 5,000 Train Loss 0.1938493251800537 Train NLL 0.19273792207241058 Train KL 1111.3997802734375
# [INFO] - 2024-05-17 16:39:01,734 - UQpy: Scientific Machine Learning: Epoch 163 / 5,000 Train Loss 0.19699393212795258 Train NLL 0.19587817788124084 Train KL 1115.747802734375
# [INFO] - 2024-05-17 16:39:01,738 - UQpy: Scientific Machine Learning: Epoch 164 / 5,000 Train Loss 0.19142377376556396 Train NLL 0.19030357897281647 Train KL 1120.200439453125
# [INFO] - 2024-05-17 16:39:01,742 - UQpy: Scientific Machine Learning: Epoch 165 / 5,000 Train Loss 0.19223417341709137 Train NLL 0.19110937416553497 Train KL 1124.80224609375
# [INFO] - 2024-05-17 16:39:01,747 - UQpy: Scientific Machine Learning: Epoch 166 / 5,000 Train Loss 0.1929594725370407 Train NLL 0.19183003902435303 Train KL 1129.4283447265625
# [INFO] - 2024-05-17 16:39:01,751 - UQpy: Scientific Machine Learning: Epoch 167 / 5,000 Train Loss 0.19174616038799286 Train NLL 0.19061210751533508 Train KL 1134.052978515625
# [INFO] - 2024-05-17 16:39:01,756 - UQpy: Scientific Machine Learning: Epoch 168 / 5,000 Train Loss 0.19024483859539032 Train NLL 0.18910595774650574 Train KL 1138.8856201171875
# [INFO] - 2024-05-17 16:39:01,760 - UQpy: Scientific Machine Learning: Epoch 169 / 5,000 Train Loss 0.19099436700344086 Train NLL 0.18985050916671753 Train KL 1143.8541259765625
# [INFO] - 2024-05-17 16:39:01,764 - UQpy: Scientific Machine Learning: Epoch 170 / 5,000 Train Loss 0.18942177295684814 Train NLL 0.18827293813228607 Train KL 1148.84228515625
# [INFO] - 2024-05-17 16:39:01,769 - UQpy: Scientific Machine Learning: Epoch 171 / 5,000 Train Loss 0.1887945830821991 Train NLL 0.18764059245586395 Train KL 1153.9896240234375
# [INFO] - 2024-05-17 16:39:01,773 - UQpy: Scientific Machine Learning: Epoch 172 / 5,000 Train Loss 0.19233736395835876 Train NLL 0.1911781281232834 Train KL 1159.2373046875
# [INFO] - 2024-05-17 16:39:01,778 - UQpy: Scientific Machine Learning: Epoch 173 / 5,000 Train Loss 0.18928849697113037 Train NLL 0.18812380731105804 Train KL 1164.6961669921875
# [INFO] - 2024-05-17 16:39:01,782 - UQpy: Scientific Machine Learning: Epoch 174 / 5,000 Train Loss 0.18799711763858795 Train NLL 0.18682663142681122 Train KL 1170.4903564453125
# [INFO] - 2024-05-17 16:39:01,787 - UQpy: Scientific Machine Learning: Epoch 175 / 5,000 Train Loss 0.18892879784107208 Train NLL 0.1877523958683014 Train KL 1176.4017333984375
# [INFO] - 2024-05-17 16:39:01,791 - UQpy: Scientific Machine Learning: Epoch 176 / 5,000 Train Loss 0.18970909714698792 Train NLL 0.18852651119232178 Train KL 1182.579345703125
# [INFO] - 2024-05-17 16:39:01,796 - UQpy: Scientific Machine Learning: Epoch 177 / 5,000 Train Loss 0.1876913160085678 Train NLL 0.18650230765342712 Train KL 1189.0067138671875
# [INFO] - 2024-05-17 16:39:01,801 - UQpy: Scientific Machine Learning: Epoch 178 / 5,000 Train Loss 0.187554731965065 Train NLL 0.18635909259319305 Train KL 1195.6375732421875
# [INFO] - 2024-05-17 16:39:01,806 - UQpy: Scientific Machine Learning: Epoch 179 / 5,000 Train Loss 0.18565623462200165 Train NLL 0.18445363640785217 Train KL 1202.5936279296875
# [INFO] - 2024-05-17 16:39:01,810 - UQpy: Scientific Machine Learning: Epoch 180 / 5,000 Train Loss 0.1863003671169281 Train NLL 0.18509040772914886 Train KL 1209.958251953125
# [INFO] - 2024-05-17 16:39:01,815 - UQpy: Scientific Machine Learning: Epoch 181 / 5,000 Train Loss 0.18447183072566986 Train NLL 0.1832541823387146 Train KL 1217.6441650390625
# [INFO] - 2024-05-17 16:39:01,820 - UQpy: Scientific Machine Learning: Epoch 182 / 5,000 Train Loss 0.18445155024528503 Train NLL 0.18322595953941345 Train KL 1225.591552734375
# [INFO] - 2024-05-17 16:39:01,825 - UQpy: Scientific Machine Learning: Epoch 183 / 5,000 Train Loss 0.1835768073797226 Train NLL 0.1823430359363556 Train KL 1233.7703857421875
# [INFO] - 2024-05-17 16:39:01,829 - UQpy: Scientific Machine Learning: Epoch 184 / 5,000 Train Loss 0.1832420825958252 Train NLL 0.18200016021728516 Train KL 1241.9276123046875
# [INFO] - 2024-05-17 16:39:01,834 - UQpy: Scientific Machine Learning: Epoch 185 / 5,000 Train Loss 0.1821698099374771 Train NLL 0.18091937899589539 Train KL 1250.4267578125
# [INFO] - 2024-05-17 16:39:01,839 - UQpy: Scientific Machine Learning: Epoch 186 / 5,000 Train Loss 0.18019036948680878 Train NLL 0.17893128097057343 Train KL 1259.0855712890625
# [INFO] - 2024-05-17 16:39:01,844 - UQpy: Scientific Machine Learning: Epoch 187 / 5,000 Train Loss 0.1788763403892517 Train NLL 0.17760823667049408 Train KL 1268.106201171875
# [INFO] - 2024-05-17 16:39:01,848 - UQpy: Scientific Machine Learning: Epoch 188 / 5,000 Train Loss 0.18093104660511017 Train NLL 0.1796538531780243 Train KL 1277.1898193359375
# [INFO] - 2024-05-17 16:39:01,853 - UQpy: Scientific Machine Learning: Epoch 189 / 5,000 Train Loss 0.17976438999176025 Train NLL 0.17847798764705658 Train KL 1286.408935546875
# [INFO] - 2024-05-17 16:39:01,857 - UQpy: Scientific Machine Learning: Epoch 190 / 5,000 Train Loss 0.17497773468494415 Train NLL 0.17368176579475403 Train KL 1295.96875
# [INFO] - 2024-05-17 16:39:01,862 - UQpy: Scientific Machine Learning: Epoch 191 / 5,000 Train Loss 0.17575876414775848 Train NLL 0.17445281147956848 Train KL 1305.958984375
# [INFO] - 2024-05-17 16:39:01,867 - UQpy: Scientific Machine Learning: Epoch 192 / 5,000 Train Loss 0.17658276855945587 Train NLL 0.1752665936946869 Train KL 1316.181640625
# [INFO] - 2024-05-17 16:39:01,871 - UQpy: Scientific Machine Learning: Epoch 193 / 5,000 Train Loss 0.16862167418003082 Train NLL 0.16729502379894257 Train KL 1326.6527099609375
# [INFO] - 2024-05-17 16:39:01,876 - UQpy: Scientific Machine Learning: Epoch 194 / 5,000 Train Loss 0.17089669406414032 Train NLL 0.16955915093421936 Train KL 1337.545654296875
# [INFO] - 2024-05-17 16:39:01,880 - UQpy: Scientific Machine Learning: Epoch 195 / 5,000 Train Loss 0.16716234385967255 Train NLL 0.16581355035305023 Train KL 1348.791259765625
# [INFO] - 2024-05-17 16:39:01,885 - UQpy: Scientific Machine Learning: Epoch 196 / 5,000 Train Loss 0.1673862636089325 Train NLL 0.16602589190006256 Train KL 1360.37353515625
# [INFO] - 2024-05-17 16:39:01,889 - UQpy: Scientific Machine Learning: Epoch 197 / 5,000 Train Loss 0.16805781424045563 Train NLL 0.16668586432933807 Train KL 1371.9547119140625
# [INFO] - 2024-05-17 16:39:01,894 - UQpy: Scientific Machine Learning: Epoch 198 / 5,000 Train Loss 0.16325150430202484 Train NLL 0.1618678867816925 Train KL 1383.6207275390625
# [INFO] - 2024-05-17 16:39:01,898 - UQpy: Scientific Machine Learning: Epoch 199 / 5,000 Train Loss 0.16228581964969635 Train NLL 0.16089025139808655 Train KL 1395.5738525390625
# [INFO] - 2024-05-17 16:39:01,902 - UQpy: Scientific Machine Learning: Epoch 200 / 5,000 Train Loss 0.1578451544046402 Train NLL 0.15643726289272308 Train KL 1407.8917236328125
# [INFO] - 2024-05-17 16:39:01,907 - UQpy: Scientific Machine Learning: Epoch 201 / 5,000 Train Loss 0.15547864139080048 Train NLL 0.15405817329883575 Train KL 1420.46337890625
# [INFO] - 2024-05-17 16:39:01,911 - UQpy: Scientific Machine Learning: Epoch 202 / 5,000 Train Loss 0.15823769569396973 Train NLL 0.15680423378944397 Train KL 1433.465087890625
# [INFO] - 2024-05-17 16:39:01,916 - UQpy: Scientific Machine Learning: Epoch 203 / 5,000 Train Loss 0.15285709500312805 Train NLL 0.15141050517559052 Train KL 1446.5933837890625
# [INFO] - 2024-05-17 16:39:01,920 - UQpy: Scientific Machine Learning: Epoch 204 / 5,000 Train Loss 0.15419326722621918 Train NLL 0.15273308753967285 Train KL 1460.18017578125
# [INFO] - 2024-05-17 16:39:01,926 - UQpy: Scientific Machine Learning: Epoch 205 / 5,000 Train Loss 0.14969870448112488 Train NLL 0.1482248306274414 Train KL 1473.875244140625
# [INFO] - 2024-05-17 16:39:01,930 - UQpy: Scientific Machine Learning: Epoch 206 / 5,000 Train Loss 0.14754368364810944 Train NLL 0.14605584740638733 Train KL 1487.83642578125
# [INFO] - 2024-05-17 16:39:01,935 - UQpy: Scientific Machine Learning: Epoch 207 / 5,000 Train Loss 0.14276306331157684 Train NLL 0.14126116037368774 Train KL 1501.8963623046875
# [INFO] - 2024-05-17 16:39:01,940 - UQpy: Scientific Machine Learning: Epoch 208 / 5,000 Train Loss 0.1392098069190979 Train NLL 0.13769349455833435 Train KL 1516.31396484375
# [INFO] - 2024-05-17 16:39:01,944 - UQpy: Scientific Machine Learning: Epoch 209 / 5,000 Train Loss 0.13774582743644714 Train NLL 0.136215478181839 Train KL 1530.3548583984375
# [INFO] - 2024-05-17 16:39:01,950 - UQpy: Scientific Machine Learning: Epoch 210 / 5,000 Train Loss 0.13734307885169983 Train NLL 0.13579830527305603 Train KL 1544.7711181640625
# [INFO] - 2024-05-17 16:39:01,955 - UQpy: Scientific Machine Learning: Epoch 211 / 5,000 Train Loss 0.1390834003686905 Train NLL 0.13752427697181702 Train KL 1559.1217041015625
# [INFO] - 2024-05-17 16:39:01,960 - UQpy: Scientific Machine Learning: Epoch 212 / 5,000 Train Loss 0.13158658146858215 Train NLL 0.13001321256160736 Train KL 1573.3734130859375
# [INFO] - 2024-05-17 16:39:01,964 - UQpy: Scientific Machine Learning: Epoch 213 / 5,000 Train Loss 0.1310279369354248 Train NLL 0.12944039702415466 Train KL 1587.5389404296875
# [INFO] - 2024-05-17 16:39:01,969 - UQpy: Scientific Machine Learning: Epoch 214 / 5,000 Train Loss 0.12856635451316833 Train NLL 0.12696494162082672 Train KL 1601.407470703125
# [INFO] - 2024-05-17 16:39:01,973 - UQpy: Scientific Machine Learning: Epoch 215 / 5,000 Train Loss 0.12553243339061737 Train NLL 0.12391696125268936 Train KL 1615.470458984375
# [INFO] - 2024-05-17 16:39:01,978 - UQpy: Scientific Machine Learning: Epoch 216 / 5,000 Train Loss 0.1201593354344368 Train NLL 0.11853034794330597 Train KL 1628.99072265625
# [INFO] - 2024-05-17 16:39:01,983 - UQpy: Scientific Machine Learning: Epoch 217 / 5,000 Train Loss 0.13296644389629364 Train NLL 0.13132408261299133 Train KL 1642.363525390625
# [INFO] - 2024-05-17 16:39:01,987 - UQpy: Scientific Machine Learning: Epoch 218 / 5,000 Train Loss 0.12575942277908325 Train NLL 0.12410466372966766 Train KL 1654.762451171875
# [INFO] - 2024-05-17 16:39:01,993 - UQpy: Scientific Machine Learning: Epoch 219 / 5,000 Train Loss 0.12664219737052917 Train NLL 0.12497587502002716 Train KL 1666.329833984375
# [INFO] - 2024-05-17 16:39:01,997 - UQpy: Scientific Machine Learning: Epoch 220 / 5,000 Train Loss 0.11989187449216843 Train NLL 0.11821405589580536 Train KL 1677.8153076171875
# [INFO] - 2024-05-17 16:39:02,002 - UQpy: Scientific Machine Learning: Epoch 221 / 5,000 Train Loss 0.12696050107479095 Train NLL 0.12527164816856384 Train KL 1688.8494873046875
# [INFO] - 2024-05-17 16:39:02,007 - UQpy: Scientific Machine Learning: Epoch 222 / 5,000 Train Loss 0.12390200793743134 Train NLL 0.12220277637243271 Train KL 1699.234619140625
# [INFO] - 2024-05-17 16:39:02,012 - UQpy: Scientific Machine Learning: Epoch 223 / 5,000 Train Loss 0.11989007890224457 Train NLL 0.11818162351846695 Train KL 1708.4542236328125
# [INFO] - 2024-05-17 16:39:02,017 - UQpy: Scientific Machine Learning: Epoch 224 / 5,000 Train Loss 0.11866889148950577 Train NLL 0.11695225536823273 Train KL 1716.6351318359375
# [INFO] - 2024-05-17 16:39:02,021 - UQpy: Scientific Machine Learning: Epoch 225 / 5,000 Train Loss 0.11316855996847153 Train NLL 0.11144424974918365 Train KL 1724.3077392578125
# [INFO] - 2024-05-17 16:39:02,026 - UQpy: Scientific Machine Learning: Epoch 226 / 5,000 Train Loss 0.11546339094638824 Train NLL 0.1137317419052124 Train KL 1731.6524658203125
# [INFO] - 2024-05-17 16:39:02,031 - UQpy: Scientific Machine Learning: Epoch 227 / 5,000 Train Loss 0.12277190387248993 Train NLL 0.12103388458490372 Train KL 1738.0194091796875
# [INFO] - 2024-05-17 16:39:02,035 - UQpy: Scientific Machine Learning: Epoch 228 / 5,000 Train Loss 0.11772153526544571 Train NLL 0.11597736179828644 Train KL 1744.1727294921875
# [INFO] - 2024-05-17 16:39:02,040 - UQpy: Scientific Machine Learning: Epoch 229 / 5,000 Train Loss 0.12152359634637833 Train NLL 0.11977331340312958 Train KL 1750.2861328125
# [INFO] - 2024-05-17 16:39:02,046 - UQpy: Scientific Machine Learning: Epoch 230 / 5,000 Train Loss 0.11050587892532349 Train NLL 0.10875017940998077 Train KL 1755.697998046875
# [INFO] - 2024-05-17 16:39:02,050 - UQpy: Scientific Machine Learning: Epoch 231 / 5,000 Train Loss 0.11181570589542389 Train NLL 0.11005415767431259 Train KL 1761.546875
# [INFO] - 2024-05-17 16:39:02,055 - UQpy: Scientific Machine Learning: Epoch 232 / 5,000 Train Loss 0.1159893348813057 Train NLL 0.11422274261713028 Train KL 1766.5906982421875
# [INFO] - 2024-05-17 16:39:02,060 - UQpy: Scientific Machine Learning: Epoch 233 / 5,000 Train Loss 0.11721260845661163 Train NLL 0.11544177681207657 Train KL 1770.833740234375
# [INFO] - 2024-05-17 16:39:02,064 - UQpy: Scientific Machine Learning: Epoch 234 / 5,000 Train Loss 0.11321214586496353 Train NLL 0.11143793910741806 Train KL 1774.2071533203125
# [INFO] - 2024-05-17 16:39:02,069 - UQpy: Scientific Machine Learning: Epoch 235 / 5,000 Train Loss 0.10877338796854019 Train NLL 0.10699627548456192 Train KL 1777.110107421875
# [INFO] - 2024-05-17 16:39:02,074 - UQpy: Scientific Machine Learning: Epoch 236 / 5,000 Train Loss 0.117879718542099 Train NLL 0.11610064655542374 Train KL 1779.0745849609375
# [INFO] - 2024-05-17 16:39:02,078 - UQpy: Scientific Machine Learning: Epoch 237 / 5,000 Train Loss 0.10386382043361664 Train NLL 0.1020827516913414 Train KL 1781.068359375
# [INFO] - 2024-05-17 16:39:02,083 - UQpy: Scientific Machine Learning: Epoch 238 / 5,000 Train Loss 0.10272210091352463 Train NLL 0.1009388118982315 Train KL 1783.2864990234375
# [INFO] - 2024-05-17 16:39:02,087 - UQpy: Scientific Machine Learning: Epoch 239 / 5,000 Train Loss 0.11670178174972534 Train NLL 0.11491638422012329 Train KL 1785.3956298828125
# [INFO] - 2024-05-17 16:39:02,092 - UQpy: Scientific Machine Learning: Epoch 240 / 5,000 Train Loss 0.100400410592556 Train NLL 0.09861233085393906 Train KL 1788.0823974609375
# [INFO] - 2024-05-17 16:39:02,097 - UQpy: Scientific Machine Learning: Epoch 241 / 5,000 Train Loss 0.11276931315660477 Train NLL 0.1109783798456192 Train KL 1790.9365234375
# [INFO] - 2024-05-17 16:39:02,101 - UQpy: Scientific Machine Learning: Epoch 242 / 5,000 Train Loss 0.10258667171001434 Train NLL 0.10079251229763031 Train KL 1794.158447265625
# [INFO] - 2024-05-17 16:39:02,106 - UQpy: Scientific Machine Learning: Epoch 243 / 5,000 Train Loss 0.10786694288253784 Train NLL 0.10606906563043594 Train KL 1797.87353515625
# [INFO] - 2024-05-17 16:39:02,111 - UQpy: Scientific Machine Learning: Epoch 244 / 5,000 Train Loss 0.10421372950077057 Train NLL 0.10241226851940155 Train KL 1801.4609375
# [INFO] - 2024-05-17 16:39:02,115 - UQpy: Scientific Machine Learning: Epoch 245 / 5,000 Train Loss 0.10884813964366913 Train NLL 0.10704295337200165 Train KL 1805.189453125
# [INFO] - 2024-05-17 16:39:02,119 - UQpy: Scientific Machine Learning: Epoch 246 / 5,000 Train Loss 0.10002061724662781 Train NLL 0.09821154922246933 Train KL 1809.06982421875
# [INFO] - 2024-05-17 16:39:02,124 - UQpy: Scientific Machine Learning: Epoch 247 / 5,000 Train Loss 0.10579121857881546 Train NLL 0.10397779941558838 Train KL 1813.421875
# [INFO] - 2024-05-17 16:39:02,129 - UQpy: Scientific Machine Learning: Epoch 248 / 5,000 Train Loss 0.10698988288640976 Train NLL 0.10517160594463348 Train KL 1818.2786865234375
# [INFO] - 2024-05-17 16:39:02,133 - UQpy: Scientific Machine Learning: Epoch 249 / 5,000 Train Loss 0.09590000659227371 Train NLL 0.09407683461904526 Train KL 1823.172119140625
# [INFO] - 2024-05-17 16:39:02,138 - UQpy: Scientific Machine Learning: Epoch 250 / 5,000 Train Loss 0.11209544539451599 Train NLL 0.11026756465435028 Train KL 1827.88037109375
# [INFO] - 2024-05-17 16:39:02,142 - UQpy: Scientific Machine Learning: Epoch 251 / 5,000 Train Loss 0.1045880988240242 Train NLL 0.10275586694478989 Train KL 1832.233642578125
# [INFO] - 2024-05-17 16:39:02,146 - UQpy: Scientific Machine Learning: Epoch 252 / 5,000 Train Loss 0.10904976725578308 Train NLL 0.10721288621425629 Train KL 1836.879150390625
# [INFO] - 2024-05-17 16:39:02,151 - UQpy: Scientific Machine Learning: Epoch 253 / 5,000 Train Loss 0.10736134648323059 Train NLL 0.10552006959915161 Train KL 1841.2757568359375
# [INFO] - 2024-05-17 16:39:02,155 - UQpy: Scientific Machine Learning: Epoch 254 / 5,000 Train Loss 0.12622784078121185 Train NLL 0.12438277900218964 Train KL 1845.0623779296875
# [INFO] - 2024-05-17 16:39:02,160 - UQpy: Scientific Machine Learning: Epoch 255 / 5,000 Train Loss 0.09448602795600891 Train NLL 0.0926380306482315 Train KL 1847.9998779296875
# [INFO] - 2024-05-17 16:39:02,164 - UQpy: Scientific Machine Learning: Epoch 256 / 5,000 Train Loss 0.09958665817975998 Train NLL 0.09773587435483932 Train KL 1850.7808837890625
# [INFO] - 2024-05-17 16:39:02,169 - UQpy: Scientific Machine Learning: Epoch 257 / 5,000 Train Loss 0.09836485236883163 Train NLL 0.09651117771863937 Train KL 1853.677734375
# [INFO] - 2024-05-17 16:39:02,174 - UQpy: Scientific Machine Learning: Epoch 258 / 5,000 Train Loss 0.09199167788028717 Train NLL 0.09013509005308151 Train KL 1856.59033203125
# [INFO] - 2024-05-17 16:39:02,179 - UQpy: Scientific Machine Learning: Epoch 259 / 5,000 Train Loss 0.09303639829158783 Train NLL 0.09117697179317474 Train KL 1859.427734375
# [INFO] - 2024-05-17 16:39:02,183 - UQpy: Scientific Machine Learning: Epoch 260 / 5,000 Train Loss 0.10705959796905518 Train NLL 0.1051969975233078 Train KL 1862.6014404296875
# [INFO] - 2024-05-17 16:39:02,188 - UQpy: Scientific Machine Learning: Epoch 261 / 5,000 Train Loss 0.09725285321474075 Train NLL 0.0953868180513382 Train KL 1866.0340576171875
# [INFO] - 2024-05-17 16:39:02,192 - UQpy: Scientific Machine Learning: Epoch 262 / 5,000 Train Loss 0.09807783365249634 Train NLL 0.0962083488702774 Train KL 1869.4879150390625
# [INFO] - 2024-05-17 16:39:02,197 - UQpy: Scientific Machine Learning: Epoch 263 / 5,000 Train Loss 0.10540121793746948 Train NLL 0.10352826118469238 Train KL 1872.9573974609375
# [INFO] - 2024-05-17 16:39:02,201 - UQpy: Scientific Machine Learning: Epoch 264 / 5,000 Train Loss 0.09825516492128372 Train NLL 0.09637950360774994 Train KL 1875.6580810546875
# [INFO] - 2024-05-17 16:39:02,206 - UQpy: Scientific Machine Learning: Epoch 265 / 5,000 Train Loss 0.09676311165094376 Train NLL 0.09488483518362045 Train KL 1878.27880859375
# [INFO] - 2024-05-17 16:39:02,211 - UQpy: Scientific Machine Learning: Epoch 266 / 5,000 Train Loss 0.09101089090108871 Train NLL 0.08912988752126694 Train KL 1881.0008544921875
# [INFO] - 2024-05-17 16:39:02,216 - UQpy: Scientific Machine Learning: Epoch 267 / 5,000 Train Loss 0.11183781921863556 Train NLL 0.10995356738567352 Train KL 1884.254638671875
# [INFO] - 2024-05-17 16:39:02,220 - UQpy: Scientific Machine Learning: Epoch 268 / 5,000 Train Loss 0.09297984838485718 Train NLL 0.09109228849411011 Train KL 1887.560791015625
# [INFO] - 2024-05-17 16:39:02,224 - UQpy: Scientific Machine Learning: Epoch 269 / 5,000 Train Loss 0.09314516186714172 Train NLL 0.09125372767448425 Train KL 1891.43408203125
# [INFO] - 2024-05-17 16:39:02,229 - UQpy: Scientific Machine Learning: Epoch 270 / 5,000 Train Loss 0.10852409899234772 Train NLL 0.1066286712884903 Train KL 1895.4239501953125
# [INFO] - 2024-05-17 16:39:02,233 - UQpy: Scientific Machine Learning: Epoch 271 / 5,000 Train Loss 0.10063814371824265 Train NLL 0.09873881936073303 Train KL 1899.322998046875
# [INFO] - 2024-05-17 16:39:02,238 - UQpy: Scientific Machine Learning: Epoch 272 / 5,000 Train Loss 0.09403722733259201 Train NLL 0.09213387966156006 Train KL 1903.34716796875
# [INFO] - 2024-05-17 16:39:02,243 - UQpy: Scientific Machine Learning: Epoch 273 / 5,000 Train Loss 0.09070181846618652 Train NLL 0.08879472315311432 Train KL 1907.0941162109375
# ...
# [INFO] - 2024-05-17 16:39:23,476 - UQpy: Scientific Machine Learning: Epoch 4,913 / 5,000 Train Loss 0.007989669218659401 Train NLL 0.0037926496006548405 Train KL 4197.01904296875
# [INFO] - 2024-05-17 16:39:23,481 - UQpy: Scientific Machine Learning: Epoch 4,914 / 5,000 Train Loss 0.006751153152436018 Train NLL 0.0025543621741235256 Train KL 4196.791015625
# [INFO] - 2024-05-17 16:39:23,485 - UQpy: Scientific Machine Learning: Epoch 4,915 / 5,000 Train Loss 0.007048308849334717 Train NLL 0.002851594239473343 Train KL 4196.71484375
# [INFO] - 2024-05-17 16:39:23,490 - UQpy: Scientific Machine Learning: Epoch 4,916 / 5,000 Train Loss 0.007443348877131939 Train NLL 0.003246725769713521 Train KL 4196.623046875
# [INFO] - 2024-05-17 16:39:23,495 - UQpy: Scientific Machine Learning: Epoch 4,917 / 5,000 Train Loss 0.007265098392963409 Train NLL 0.003068480407819152 Train KL 4196.61767578125
# [INFO] - 2024-05-17 16:39:23,499 - UQpy: Scientific Machine Learning: Epoch 4,918 / 5,000 Train Loss 0.006789657287299633 Train NLL 0.002592923352494836 Train KL 4196.734375
# [INFO] - 2024-05-17 16:39:23,504 - UQpy: Scientific Machine Learning: Epoch 4,919 / 5,000 Train Loss 0.006787426769733429 Train NLL 0.0025905228685587645 Train KL 4196.90380859375
# [INFO] - 2024-05-17 16:39:23,508 - UQpy: Scientific Machine Learning: Epoch 4,920 / 5,000 Train Loss 0.007494309917092323 Train NLL 0.003297640709206462 Train KL 4196.66943359375
# [INFO] - 2024-05-17 16:39:23,513 - UQpy: Scientific Machine Learning: Epoch 4,921 / 5,000 Train Loss 0.007570524699985981 Train NLL 0.0033741756342351437 Train KL 4196.34912109375
# [INFO] - 2024-05-17 16:39:23,517 - UQpy: Scientific Machine Learning: Epoch 4,922 / 5,000 Train Loss 0.006379111669957638 Train NLL 0.0021832541096955538 Train KL 4195.85791015625
# [INFO] - 2024-05-17 16:39:23,522 - UQpy: Scientific Machine Learning: Epoch 4,923 / 5,000 Train Loss 0.007649907376617193 Train NLL 0.003454641904681921 Train KL 4195.265625
# [INFO] - 2024-05-17 16:39:23,526 - UQpy: Scientific Machine Learning: Epoch 4,924 / 5,000 Train Loss 0.007858913391828537 Train NLL 0.0036640469916164875 Train KL 4194.86669921875
# [INFO] - 2024-05-17 16:39:23,531 - UQpy: Scientific Machine Learning: Epoch 4,925 / 5,000 Train Loss 0.008831234648823738 Train NLL 0.004636709578335285 Train KL 4194.5244140625
# [INFO] - 2024-05-17 16:39:23,536 - UQpy: Scientific Machine Learning: Epoch 4,926 / 5,000 Train Loss 0.00869331881403923 Train NLL 0.004499008879065514 Train KL 4194.31005859375
# [INFO] - 2024-05-17 16:39:23,541 - UQpy: Scientific Machine Learning: Epoch 4,927 / 5,000 Train Loss 0.008089273236691952 Train NLL 0.0038957116194069386 Train KL 4193.5615234375
# [INFO] - 2024-05-17 16:39:23,546 - UQpy: Scientific Machine Learning: Epoch 4,928 / 5,000 Train Loss 0.008117510005831718 Train NLL 0.00392454257234931 Train KL 4192.966796875
# [INFO] - 2024-05-17 16:39:23,551 - UQpy: Scientific Machine Learning: Epoch 4,929 / 5,000 Train Loss 0.008550811558961868 Train NLL 0.004358437843620777 Train KL 4192.3740234375
# [INFO] - 2024-05-17 16:39:23,555 - UQpy: Scientific Machine Learning: Epoch 4,930 / 5,000 Train Loss 0.006783216260373592 Train NLL 0.0025910090189427137 Train KL 4192.20751953125
# [INFO] - 2024-05-17 16:39:23,560 - UQpy: Scientific Machine Learning: Epoch 4,931 / 5,000 Train Loss 0.008281504735350609 Train NLL 0.004089212045073509 Train KL 4192.29296875
# [INFO] - 2024-05-17 16:39:23,564 - UQpy: Scientific Machine Learning: Epoch 4,932 / 5,000 Train Loss 0.006550396326929331 Train NLL 0.002358464989811182 Train KL 4191.93115234375
# [INFO] - 2024-05-17 16:39:23,569 - UQpy: Scientific Machine Learning: Epoch 4,933 / 5,000 Train Loss 0.006362792104482651 Train NLL 0.0021713832393288612 Train KL 4191.40869140625
# [INFO] - 2024-05-17 16:39:23,573 - UQpy: Scientific Machine Learning: Epoch 4,934 / 5,000 Train Loss 0.006669140886515379 Train NLL 0.0024783629924058914 Train KL 4190.77783203125
# [INFO] - 2024-05-17 16:39:23,578 - UQpy: Scientific Machine Learning: Epoch 4,935 / 5,000 Train Loss 0.006532787345349789 Train NLL 0.0023422983940690756 Train KL 4190.48876953125
# [INFO] - 2024-05-17 16:39:23,582 - UQpy: Scientific Machine Learning: Epoch 4,936 / 5,000 Train Loss 0.009057343006134033 Train NLL 0.004866933915764093 Train KL 4190.40966796875
# [INFO] - 2024-05-17 16:39:23,587 - UQpy: Scientific Machine Learning: Epoch 4,937 / 5,000 Train Loss 0.007448586635291576 Train NLL 0.003258056240156293 Train KL 4190.53076171875
# [INFO] - 2024-05-17 16:39:23,591 - UQpy: Scientific Machine Learning: Epoch 4,938 / 5,000 Train Loss 0.006699537858366966 Train NLL 0.0025086805690079927 Train KL 4190.857421875
# [INFO] - 2024-05-17 16:39:23,596 - UQpy: Scientific Machine Learning: Epoch 4,939 / 5,000 Train Loss 0.007168940734118223 Train NLL 0.002977682277560234 Train KL 4191.25830078125
# [INFO] - 2024-05-17 16:39:23,601 - UQpy: Scientific Machine Learning: Epoch 4,940 / 5,000 Train Loss 0.008318891748785973 Train NLL 0.004127279855310917 Train KL 4191.61181640625
# [INFO] - 2024-05-17 16:39:23,606 - UQpy: Scientific Machine Learning: Epoch 4,941 / 5,000 Train Loss 0.007264910731464624 Train NLL 0.0030731274746358395 Train KL 4191.783203125
# [INFO] - 2024-05-17 16:39:23,611 - UQpy: Scientific Machine Learning: Epoch 4,942 / 5,000 Train Loss 0.010179920122027397 Train NLL 0.005987968295812607 Train KL 4191.951171875
# [INFO] - 2024-05-17 16:39:23,615 - UQpy: Scientific Machine Learning: Epoch 4,943 / 5,000 Train Loss 0.007297459524124861 Train NLL 0.0031051523983478546 Train KL 4192.30712890625
# [INFO] - 2024-05-17 16:39:23,620 - UQpy: Scientific Machine Learning: Epoch 4,944 / 5,000 Train Loss 0.007698439061641693 Train NLL 0.0035057603381574154 Train KL 4192.6787109375
# [INFO] - 2024-05-17 16:39:23,624 - UQpy: Scientific Machine Learning: Epoch 4,945 / 5,000 Train Loss 0.008320475928485394 Train NLL 0.0041272700764238834 Train KL 4193.2060546875
# [INFO] - 2024-05-17 16:39:23,628 - UQpy: Scientific Machine Learning: Epoch 4,946 / 5,000 Train Loss 0.007337087765336037 Train NLL 0.0031436432618647814 Train KL 4193.44482421875
# [INFO] - 2024-05-17 16:39:23,633 - UQpy: Scientific Machine Learning: Epoch 4,947 / 5,000 Train Loss 0.007459371816366911 Train NLL 0.003265921026468277 Train KL 4193.45068359375
# [INFO] - 2024-05-17 16:39:23,638 - UQpy: Scientific Machine Learning: Epoch 4,948 / 5,000 Train Loss 0.0076005952432751656 Train NLL 0.0034073996357619762 Train KL 4193.19580078125
# [INFO] - 2024-05-17 16:39:23,642 - UQpy: Scientific Machine Learning: Epoch 4,949 / 5,000 Train Loss 0.008060382679104805 Train NLL 0.0038677272386848927 Train KL 4192.65576171875
# [INFO] - 2024-05-17 16:39:23,646 - UQpy: Scientific Machine Learning: Epoch 4,950 / 5,000 Train Loss 0.00782819464802742 Train NLL 0.0036361825186759233 Train KL 4192.01220703125
# [INFO] - 2024-05-17 16:39:23,651 - UQpy: Scientific Machine Learning: Epoch 4,951 / 5,000 Train Loss 0.007416319102048874 Train NLL 0.0032250932417809963 Train KL 4191.22607421875
# [INFO] - 2024-05-17 16:39:23,655 - UQpy: Scientific Machine Learning: Epoch 4,952 / 5,000 Train Loss 0.007394635584205389 Train NLL 0.003203840460628271 Train KL 4190.794921875
# [INFO] - 2024-05-17 16:39:23,660 - UQpy: Scientific Machine Learning: Epoch 4,953 / 5,000 Train Loss 0.006864793598651886 Train NLL 0.0026741318870335817 Train KL 4190.662109375
# [INFO] - 2024-05-17 16:39:23,666 - UQpy: Scientific Machine Learning: Epoch 4,954 / 5,000 Train Loss 0.006777299102395773 Train NLL 0.0025865198113024235 Train KL 4190.779296875
# [INFO] - 2024-05-17 16:39:23,671 - UQpy: Scientific Machine Learning: Epoch 4,955 / 5,000 Train Loss 0.006691459100693464 Train NLL 0.0025006700307130814 Train KL 4190.7890625
# [INFO] - 2024-05-17 16:39:23,675 - UQpy: Scientific Machine Learning: Epoch 4,956 / 5,000 Train Loss 0.007156153675168753 Train NLL 0.0029655410908162594 Train KL 4190.61279296875
# [INFO] - 2024-05-17 16:39:23,680 - UQpy: Scientific Machine Learning: Epoch 4,957 / 5,000 Train Loss 0.007499606814235449 Train NLL 0.003309281077235937 Train KL 4190.32568359375
# [INFO] - 2024-05-17 16:39:23,684 - UQpy: Scientific Machine Learning: Epoch 4,958 / 5,000 Train Loss 0.007910694926977158 Train NLL 0.0037205584812909365 Train KL 4190.13671875
# [INFO] - 2024-05-17 16:39:23,688 - UQpy: Scientific Machine Learning: Epoch 4,959 / 5,000 Train Loss 0.007480002008378506 Train NLL 0.003289897693321109 Train KL 4190.1044921875
# [INFO] - 2024-05-17 16:39:23,693 - UQpy: Scientific Machine Learning: Epoch 4,960 / 5,000 Train Loss 0.007651378400623798 Train NLL 0.0034615949261933565 Train KL 4189.783203125
# [INFO] - 2024-05-17 16:39:23,697 - UQpy: Scientific Machine Learning: Epoch 4,961 / 5,000 Train Loss 0.008298086933791637 Train NLL 0.004108451772481203 Train KL 4189.63525390625
# [INFO] - 2024-05-17 16:39:23,702 - UQpy: Scientific Machine Learning: Epoch 4,962 / 5,000 Train Loss 0.00696721114218235 Train NLL 0.0027780893724411726 Train KL 4189.1220703125
# [INFO] - 2024-05-17 16:39:23,706 - UQpy: Scientific Machine Learning: Epoch 4,963 / 5,000 Train Loss 0.007935202680528164 Train NLL 0.003746638773009181 Train KL 4188.56396484375
# [INFO] - 2024-05-17 16:39:23,711 - UQpy: Scientific Machine Learning: Epoch 4,964 / 5,000 Train Loss 0.007504972629249096 Train NLL 0.003316841321066022 Train KL 4188.130859375
# [INFO] - 2024-05-17 16:39:23,715 - UQpy: Scientific Machine Learning: Epoch 4,965 / 5,000 Train Loss 0.007785245776176453 Train NLL 0.0035971645265817642 Train KL 4188.0810546875
# [INFO] - 2024-05-17 16:39:23,719 - UQpy: Scientific Machine Learning: Epoch 4,966 / 5,000 Train Loss 0.007716811262071133 Train NLL 0.003528426168486476 Train KL 4188.38525390625
# [INFO] - 2024-05-17 16:39:23,724 - UQpy: Scientific Machine Learning: Epoch 4,967 / 5,000 Train Loss 0.007863097824156284 Train NLL 0.0036743904929608107 Train KL 4188.70703125
# [INFO] - 2024-05-17 16:39:23,729 - UQpy: Scientific Machine Learning: Epoch 4,968 / 5,000 Train Loss 0.008703578263521194 Train NLL 0.0045145186595618725 Train KL 4189.0595703125
# [INFO] - 2024-05-17 16:39:23,734 - UQpy: Scientific Machine Learning: Epoch 4,969 / 5,000 Train Loss 0.007096245419234037 Train NLL 0.0029070735909044743 Train KL 4189.171875
# [INFO] - 2024-05-17 16:39:23,738 - UQpy: Scientific Machine Learning: Epoch 4,970 / 5,000 Train Loss 0.007994178682565689 Train NLL 0.0038049505092203617 Train KL 4189.2275390625
# [INFO] - 2024-05-17 16:39:23,743 - UQpy: Scientific Machine Learning: Epoch 4,971 / 5,000 Train Loss 0.007717052940279245 Train NLL 0.0035280920565128326 Train KL 4188.9609375
# [INFO] - 2024-05-17 16:39:23,747 - UQpy: Scientific Machine Learning: Epoch 4,972 / 5,000 Train Loss 0.008865052834153175 Train NLL 0.004676359239965677 Train KL 4188.693359375
# [INFO] - 2024-05-17 16:39:23,752 - UQpy: Scientific Machine Learning: Epoch 4,973 / 5,000 Train Loss 0.007325118873268366 Train NLL 0.003136584535241127 Train KL 4188.5341796875
# [INFO] - 2024-05-17 16:39:23,756 - UQpy: Scientific Machine Learning: Epoch 4,974 / 5,000 Train Loss 0.009018739685416222 Train NLL 0.0048304833471775055 Train KL 4188.2568359375
# [INFO] - 2024-05-17 16:39:23,761 - UQpy: Scientific Machine Learning: Epoch 4,975 / 5,000 Train Loss 0.008341098204255104 Train NLL 0.004152860026806593 Train KL 4188.23876953125
# [INFO] - 2024-05-17 16:39:23,766 - UQpy: Scientific Machine Learning: Epoch 4,976 / 5,000 Train Loss 0.006078700069338083 Train NLL 0.001889972947537899 Train KL 4188.72705078125
# [INFO] - 2024-05-17 16:39:23,771 - UQpy: Scientific Machine Learning: Epoch 4,977 / 5,000 Train Loss 0.0073750559240579605 Train NLL 0.0031858652364462614 Train KL 4189.1904296875
# [INFO] - 2024-05-17 16:39:23,775 - UQpy: Scientific Machine Learning: Epoch 4,978 / 5,000 Train Loss 0.007147257216274738 Train NLL 0.0029572893399745226 Train KL 4189.96826171875
# [INFO] - 2024-05-17 16:39:23,780 - UQpy: Scientific Machine Learning: Epoch 4,979 / 5,000 Train Loss 0.007710506673902273 Train NLL 0.0035197162069380283 Train KL 4190.79052734375
# [INFO] - 2024-05-17 16:39:23,784 - UQpy: Scientific Machine Learning: Epoch 4,980 / 5,000 Train Loss 0.006345970090478659 Train NLL 0.0021544736810028553 Train KL 4191.49658203125
# [INFO] - 2024-05-17 16:39:23,788 - UQpy: Scientific Machine Learning: Epoch 4,981 / 5,000 Train Loss 0.0069914450868964195 Train NLL 0.0027992811519652605 Train KL 4192.1640625
# [INFO] - 2024-05-17 16:39:23,794 - UQpy: Scientific Machine Learning: Epoch 4,982 / 5,000 Train Loss 0.008260607719421387 Train NLL 0.004067858215421438 Train KL 4192.74951171875
# [INFO] - 2024-05-17 16:39:23,799 - UQpy: Scientific Machine Learning: Epoch 4,983 / 5,000 Train Loss 0.007869505323469639 Train NLL 0.0036767080891877413 Train KL 4192.796875
# [INFO] - 2024-05-17 16:39:23,803 - UQpy: Scientific Machine Learning: Epoch 4,984 / 5,000 Train Loss 0.00782260112464428 Train NLL 0.0036300159990787506 Train KL 4192.5849609375
# [INFO] - 2024-05-17 16:39:23,808 - UQpy: Scientific Machine Learning: Epoch 4,985 / 5,000 Train Loss 0.007885146886110306 Train NLL 0.0036932844668626785 Train KL 4191.86279296875
# [INFO] - 2024-05-17 16:39:23,812 - UQpy: Scientific Machine Learning: Epoch 4,986 / 5,000 Train Loss 0.00848056748509407 Train NLL 0.004289728589355946 Train KL 4190.83837890625
# [INFO] - 2024-05-17 16:39:23,817 - UQpy: Scientific Machine Learning: Epoch 4,987 / 5,000 Train Loss 0.006286266725510359 Train NLL 0.002096394542604685 Train KL 4189.8720703125
# [INFO] - 2024-05-17 16:39:23,822 - UQpy: Scientific Machine Learning: Epoch 4,988 / 5,000 Train Loss 0.007626891136169434 Train NLL 0.003437978681176901 Train KL 4188.91259765625
# [INFO] - 2024-05-17 16:39:23,827 - UQpy: Scientific Machine Learning: Epoch 4,989 / 5,000 Train Loss 0.008426625281572342 Train NLL 0.0042386362329125404 Train KL 4187.9892578125
# [INFO] - 2024-05-17 16:39:23,832 - UQpy: Scientific Machine Learning: Epoch 4,990 / 5,000 Train Loss 0.0069016944617033005 Train NLL 0.0027146530337631702 Train KL 4187.04150390625
# [INFO] - 2024-05-17 16:39:23,836 - UQpy: Scientific Machine Learning: Epoch 4,991 / 5,000 Train Loss 0.007182593457400799 Train NLL 0.002996366238221526 Train KL 4186.2275390625
# [INFO] - 2024-05-17 16:39:23,841 - UQpy: Scientific Machine Learning: Epoch 4,992 / 5,000 Train Loss 0.008164756000041962 Train NLL 0.0039789676666259766 Train KL 4185.7880859375
# [INFO] - 2024-05-17 16:39:23,845 - UQpy: Scientific Machine Learning: Epoch 4,993 / 5,000 Train Loss 0.007137239910662174 Train NLL 0.002951675094664097 Train KL 4185.56494140625
# [INFO] - 2024-05-17 16:39:23,849 - UQpy: Scientific Machine Learning: Epoch 4,994 / 5,000 Train Loss 0.007958043366670609 Train NLL 0.003772605210542679 Train KL 4185.4384765625
# [INFO] - 2024-05-17 16:39:23,854 - UQpy: Scientific Machine Learning: Epoch 4,995 / 5,000 Train Loss 0.007089351303875446 Train NLL 0.0029039971996098757 Train KL 4185.3544921875
# [INFO] - 2024-05-17 16:39:23,858 - UQpy: Scientific Machine Learning: Epoch 4,996 / 5,000 Train Loss 0.007232325151562691 Train NLL 0.003046690486371517 Train KL 4185.634765625
# [INFO] - 2024-05-17 16:39:23,863 - UQpy: Scientific Machine Learning: Epoch 4,997 / 5,000 Train Loss 0.008396811783313751 Train NLL 0.0042105927132070065 Train KL 4186.2197265625
# [INFO] - 2024-05-17 16:39:23,867 - UQpy: Scientific Machine Learning: Epoch 4,998 / 5,000 Train Loss 0.008346186950802803 Train NLL 0.0041592917405068874 Train KL 4186.8955078125
# [INFO] - 2024-05-17 16:39:23,872 - UQpy: Scientific Machine Learning: Epoch 4,999 / 5,000 Train Loss 0.007731637917459011 Train NLL 0.003544037463143468 Train KL 4187.60009765625
# [INFO] - 2024-05-17 16:39:23,876 - UQpy: Scientific Machine Learning: Epoch 5,000 / 5,000 Train Loss 0.007026723586022854 Train NLL 0.002838610438629985 Train KL 4188.11328125
# [INFO] - 2024-05-17 16:39:23,876 - UQpy: Scientific Machine Learning: Completed training FeedForwardNeuralNetwork
# done

# %% [markdown]
# We perdict the outputs for the test examples using the trained model. model.train(False) and model.sample(False) ensures that the mean of the parameters are used for predicting the outputs. When one of these is True, samples are drawn from the distribution of the parameters to make predictions.

# %%
# Plotting Results
x = SinusoidalDataset().x
y = SinusoidalDataset().y
x_val = torch.linspace(-1, 1, 1000).view(-1,1)
y_val = (0.4 * torch.sin(4 * x_val) + 0.5 * torch.cos(12 * x_val))
model.train(False)
model.sample(False);

# %% [markdown]
# We visualize the predictions using the following plots.

# %%
pred_val = model(x_val)

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(
    x.detach().numpy(),
    y.detach().numpy(), '*',
    label="Data", color='crimson', markersize=10
)
ax.plot(
    x_val.detach().numpy(),
    pred_val.detach().numpy(),
    label="Final Prediction",
    color='navy', linewidth=2
)
ax.plot(
    x_val.detach(), y_val.detach(),
    label="Exact",
    color="black",
    linestyle="dashed",
    linewidth=2
)

# Customize the plot
ax.set_title("Prediction", fontsize=16, fontweight='bold')
ax.set_xlabel("x", fontsize=14)
ax.set_ylabel("f(x)", fontsize=14)
ax.legend(loc='upper right', fontsize=12)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Improve the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Convergence of the loss function is shown in the following.

# %%
train_loss = trainer.history["train_loss"].detach().numpy()
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(train_loss)


# Customize the plot
ax.set_title("Bayes By Backpropagation Training Loss", fontsize=16, fontweight='bold')
ax.set_xlabel("Epoch", fontsize=14)
ax.set_ylabel("Loss", fontsize=14)
ax.legend(loc='upper right', fontsize=12)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Improve the layout
plt.tight_layout()
plt.show()

# %% [markdown]
# We perform uncertainty quantification by sampling the parameters of the model $n$ times and predicting the output for each of these sample parameters. The variance in the prediction gives us measure of epistemic uncertianty. The total uncertainty
# $$ \sigma_{total}^2 = \sigma_{epistemic}^2 + \sigma_{aleatoric}^2 $$

# %%
model.sample(False)
mean = model(x_val)
model.sample(True)
n = 1000
samples = torch.zeros(len(x_val), n)
for i in range(n):
    samples[:, i] = model(x_val).squeeze()
variance = torch.var(samples, dim=1)
standard_deviation = torch.sqrt(variance)

x_plot = x.squeeze().detach().numpy()
mu = mean.squeeze().detach().numpy()
sigma = standard_deviation.squeeze().detach().numpy()
total_sigma = np.sqrt(sigma**2 + 0.05**2)

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the mean prediction
ax.plot(x_val, mu, label="Mean Prediction", color='navy', linewidth=2)

# Plot the data points
ax.plot(
    x.detach().numpy(),
    y.detach().numpy(), '*',
    label="Data", color='crimson', markersize=10
)

# Fill the uncertainties
ax.fill_between(
    x_val.view(-1).detach(), mu - (3 * sigma), mu + (3 * sigma), 
    label="Epistemic Uncertainty", color='skyblue', alpha=0.6
)
ax.fill_between(
    x_val.view(-1).detach(), mu - (3 * total_sigma), mu + (3 * total_sigma), 
    label="Total Uncertainty", color='lightcoral', alpha=0.3
)

# Customize the plot
ax.set_title("Bayesian Neural Network $\mu \pm 3\sigma$", fontsize=16, fontweight='bold')
ax.set_xlabel("x", fontsize=14)
ax.set_ylabel("f(x)", fontsize=14)
ax.legend(loc='upper right', fontsize=12)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Improve the layout
plt.tight_layout()

# Show the plot
plt.show()
